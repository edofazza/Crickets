# %% [markdown]
# # Imports

# %%
import os
import numpy as np

# %% [markdown]
# # Load the Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Download the `prediction_npy.zip ` from Google Drive (https://drive.google.com/drive/folders/1xzN19rTxewEiwzeBN3g88w5UBN2Z0Z0S?usp=share_link) and add it to your Drive or local directory if you are not using Google Colab.
#
# Next step is to unzip the file.

# %%
! unzip "predictions_npy.zip"
# Out:
# Archive:  /content/drive/MyDrive/PhD/crickets/paper title/data/predictions_npy.zip
#    creating: predictions_npy/
#   inflating: __MACOSX/._predictions_npy
#    creating: predictions_npy/sugar/
#    creating: predictions_npy/control/
#    creating: predictions_npy/ammonia/
#    creating: predictions_npy/sugar/test/
#    creating: predictions_npy/sugar/train/
#    creating: predictions_npy/sugar/val/
#    creating: predictions_npy/control/test/
#    creating: predictions_npy/control/train/
#    creating: predictions_npy/control/val/
#    creating: predictions_npy/ammonia/test/
#    creating: predictions_npy/ammonia/train/
#    creating: predictions_npy/ammonia/val/
#   inflating: predictions_npy/sugar/test/C43_S.npy
#   inflating: predictions_npy/sugar/test/C45_S.npy
#   inflating: predictions_npy/sugar/test/C42_S.npy
#   inflating: predictions_npy/sugar/test/C46_S.npy
#   inflating: predictions_npy/sugar/test/C44_S.npy
#   inflating: predictions_npy/sugar/train/C30_S.npy
#   inflating: predictions_npy/sugar/train/C29_S.npy
#   inflating: predictions_npy/sugar/train/C32_S.npy
#   inflating: predictions_npy/sugar/train/C36_S.npy
#   inflating: predictions_npy/sugar/train/C34_S.npy
#   inflating: predictions_npy/sugar/train/C33_S.npy
#   inflating: predictions_npy/sugar/train/C31_S.npy
#   inflating: predictions_npy/sugar/train/C28_S.npy
#   inflating: predictions_npy/sugar/train/C35_S.npy
#   inflating: predictions_npy/sugar/train/C37_S.npy
#   inflating: predictions_npy/sugar/train/C24_S.npy
#   inflating: predictions_npy/sugar/train/C26_S.npy
#   inflating: predictions_npy/sugar/train/C27_S.npy
#   inflating: predictions_npy/sugar/train/C25_S.npy
#   inflating: predictions_npy/sugar/val/C39_S.npy
#   inflating: predictions_npy/sugar/val/C41_S.npy
#   inflating: predictions_npy/sugar/val/C40_S.npy
#   inflating: predictions_npy/sugar/val/C38_S.npy
#   inflating: predictions_npy/control/test/C19_C.npy
#   inflating: predictions_npy/control/test/C22_C.npy
#   inflating: predictions_npy/control/test/C20_C.npy
#   inflating: predictions_npy/control/test/C21_C.npy
#   inflating: predictions_npy/control/test/C23_C.npy
#   inflating: predictions_npy/control/train/C12_C.npy
#   inflating: predictions_npy/control/train/C9_C.npy
#   inflating: predictions_npy/control/train/C10_C.npy
#   inflating: predictions_npy/control/train/C14_C.npy
#   inflating: predictions_npy/control/train/C8_C.npy
#   inflating: predictions_npy/control/train/C11_C.npy
#   inflating: predictions_npy/control/train/C13_C.npy
#   inflating: predictions_npy/control/train/C2_C.npy
#   inflating: predictions_npy/control/train/C6_C.npy
#   inflating: predictions_npy/control/train/C4_C.npy
#   inflating: predictions_npy/control/train/C3_C.npy
#   inflating: predictions_npy/control/train/C1_C.npy
#   inflating: predictions_npy/control/train/C5_C.npy
#   inflating: predictions_npy/control/train/C7_C.npy
#   inflating: predictions_npy/control/val/C16_C.npy
#   inflating: predictions_npy/control/val/C17_C.npy
#   inflating: predictions_npy/control/val/C15_C.npy
#   inflating: predictions_npy/control/val/C18_C.npy
#   inflating: predictions_npy/ammonia/test/C68_A.npy
#   inflating: predictions_npy/ammonia/test/C69_A.npy
#   inflating: predictions_npy/ammonia/test/C65_A.npy
#   inflating: predictions_npy/ammonia/test/C67_A.npy
#   inflating: predictions_npy/ammonia/test/C66_A.npy
#   inflating: predictions_npy/ammonia/train/C55_A.npy
#   inflating: predictions_npy/ammonia/train/C57_A.npy
#   inflating: predictions_npy/ammonia/train/C53_A.npy
#   inflating: predictions_npy/ammonia/train/C48_A.npy
#   inflating: predictions_npy/ammonia/train/C51_A.npy
#   inflating: predictions_npy/ammonia/train/C56_A.npy
#   inflating: predictions_npy/ammonia/train/C54_A.npy
#   inflating: predictions_npy/ammonia/train/C49_A.npy
#   inflating: predictions_npy/ammonia/train/C50_A.npy
#   inflating: predictions_npy/ammonia/train/C52_A.npy
#   inflating: predictions_npy/ammonia/train/C47_A.npy
#   inflating: predictions_npy/ammonia/train/C58_A.npy
#   inflating: predictions_npy/ammonia/train/C60_A.npy
#   inflating: predictions_npy/ammonia/train/C59_A.npy
#   inflating: predictions_npy/ammonia/val/C63_A.npy
#   inflating: predictions_npy/ammonia/val/C61_A.npy
#   inflating: predictions_npy/ammonia/val/C62_A.npy
#   inflating: predictions_npy/ammonia/val/C64_A.npy

# %% [markdown]
# # Utility Functions/Classes
# To perform the conversion from the numpy obtained converting the slp predictions to the final sequence where the head is the center of the cartesian plane some *functions* and a *class* are needed.

# %% [markdown]
# ## Handling missing values
# The class takes a one-dimensional sequence (aka, list) and can perform missing value analysis, and interpolate missing values.
# In the code the class is located in `utils.missingvalues`.

# %%
class MissingValuesHandler:
    def __init__(self, pred):
        """
        Check if the first value of pred is not NaN, if so it is changed to the
        closest not NaN value.
        :param pred: Single prediction sequence
        """
        self.pred = pred
        if np.isnan(self.pred[0]):
            i = 1
            while True:
                if not np.isnan(self.pred[i]):
                    self.pred[0] = self.pred[i]
                    break
                i += 1

    def find_missing_values(self):
        """

        :return: a list of all the indexes where the keypoint is NaN
        """
        missing = []
        for i, v in enumerate(self.pred):
            if np.isnan(v):
                missing.append(i)
        return missing

    def fill_missing_values(self):
        """
        Filling the missing values using a simple average method between the antecedent
        and the first not-nan-value.
        :return: a list containing the predictions
        """
        new_pred = []
        for i, v in enumerate(self.pred):
            if np.isnan(v):
                prev = new_pred[i - 1]
                subs = None

                for j in range(i + 1, len(self.pred)):
                    subs = self.pred[j]
                    if np.isnan(subs):
                        subs = None  # generalize in the case is the last the one missing
                        continue
                    else:
                        break
                if subs is None:
                    new_pred.append(prev)
                else:
                    new_pred.append((prev + subs) / 2)
            else:
                new_pred.append(v)

        return new_pred

    def fill_missing_values_weighted(self):
        """
        Filling the missing values using a weighted average method between the antecedent
        and the first not-nan-value. This method gives more important to the value closest
        to the missing one.
        :return: a list containing the predictions
        """
        new_pred = []
        for i, v in enumerate(self.pred):
            if np.isnan(v):
                prev = new_pred[i - 1]
                subs = None
                k = 0

                for j in range(i + 1, len(self.pred)):
                    k += 1
                    subs = self.pred[j]
                    if np.isnan(subs):
                        subs = None  # generalize in the case is the last the one missing
                        continue
                    else:
                        break
                if subs is None:
                    new_pred.append(prev)
                else:
                    alpha = 1 / k
                    new_pred.append((prev + alpha * subs) / (1 + alpha))
            else:
                new_pred.append(v)

        return new_pred

# %% [markdown]
# Functions that uses the above class to perform the filling operation outputing also some information related to the missing values, such as how many missing values for a particular joint in a specific sequence.
#
# The `prediction_npy_path` is the path to the unzipped file. On the other hand, `filled_prediction_path` is the path to a new directory (i.e., not yet existing) or an empty directory where the new sequences will be saved using the same structure used in the `predictions_npy` directory.
#
# The code of this function can be found in `utils.missingvalues`.

# %%
def from_pred_to_filled_pred(prediction_npy_path, filled_prediction_path):
    if not os.path.exists(filled_prediction_path):
        os.mkdir(filled_prediction_path)

    classes = os.listdir(prediction_npy_path)
    for c in classes:  # control sugar ammonia
        if c not in ['control', 'sugar', 'ammonia']:
            continue
        class_path = os.path.join(prediction_npy_path, c)  # predictions_npy/control
        sets = os.listdir(class_path)

        filled_class_path = os.path.join(filled_prediction_path, c)
        os.mkdir(filled_class_path)

        for s in sets:
            if s not in ['train', 'test', 'val']:
                continue
            set_path = os.path.join(class_path, s)  # predictions_npy/control/train
            predictions = [prediction for prediction in os.listdir(set_path) if prediction.endswith('.npy')]

            filled_set_path = os.path.join(filled_class_path, s)
            os.mkdir(filled_set_path)

            for prediction in predictions:
                pred = np.load(os.path.join(set_path, prediction)).T
                print(prediction)
                print(f'\t-Shape: {pred.shape}')

                for i, row in enumerate(pred):
                    mvh = MissingValuesHandler(row)
                    missing = mvh.find_missing_values()
                    print(f'\t-Missing values for entry {i}: {len(missing)}')
                    if len(missing) == 0:
                        print(f'\tNo missing values for entry {i}, filling operation skipped')
                    else:
                        pred[i] = mvh.fill_missing_values_weighted()
                np.save(os.path.join(filled_set_path, prediction), pred)

# %% [markdown]
# ## Obtain the centralized numpy
# From the filled prediction directory we can use the following functions to centralized the head position to (0,0) and move all the keypoints in the frames accordingly to the new arragement. Since now the information related to the head (i.e., x and y position) is not meaningful the sequences related to it are removed from the overall sequence.
#
# In the code these functions are located in `utils.head_centralization`

# %%
def centralized_head_in_sequence(sequence_path, output_path):
    pred = np.load(sequence_path).T

    for frame in pred:
        x_head, y_head = frame[0], frame[1]
        for i in range(0, len(frame), 2):
            frame[i] = frame[i] - x_head
            frame[i + 1] = frame[i + 1] - y_head
    pred = pred.T[2:, :]
    print(pred.shape)
    np.save(output_path, pred)


def centralized_head_sequence_from_dir(dir_path, output_dir_path):
    predictions = [prediction for prediction in os.listdir(dir_path) if prediction.endswith('.npy')]

    if not os.path.exists(output_dir_path):
        os.mkdir(output_dir_path)

    for prediction in predictions:
        centralized_head_in_sequence(os.path.join(dir_path, prediction), os.path.join(output_dir_path, prediction))


def centralized_head_sequence_from_project(project_path, output_path):
    if not os.path.exists(output_path):
        os.mkdir(output_path)

    classes = os.listdir(project_path)
    for c in classes:  # control sugar ammonia
        if c not in ['control', 'sugar', 'ammonia']:
            continue
        class_path = os.path.join(project_path, c)  # predictions_npy/control
        sets = os.listdir(class_path)

        filled_class_path = os.path.join(output_path, c)
        os.mkdir(filled_class_path)

        for s in sets:
            if s not in ['train', 'test', 'val']:
                continue
            centralized_head_sequence_from_dir(os.path.join(class_path, s), os.path.join(filled_class_path, s))

# %% [markdown]
# # Perform Filling and Transformation
# Here the filling operation and the head centralization is performed. Change the path-variables to what you want to locate the file.

# %%
prediction_npy_path = 'predictions_npy' # CHANGE HERE
filled_prediction_path = 'predictions_filled' # CHANGE HERE
centered_prediction_path = 'prediction_head_centered' # CHANGE HERE

from_pred_to_filled_pred(prediction_npy_path, filled_prediction_path)
centralized_head_sequence_from_project(filled_prediction_path, centered_prediction_path)
# Out:
# C20_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 132
# 	-Missing values for entry 1: 132
# 	-Missing values for entry 2: 137
# 	-Missing values for entry 3: 137
# 	-Missing values for entry 4: 259
# 	-Missing values for entry 5: 259
# 	-Missing values for entry 6: 139
# 	-Missing values for entry 7: 139
# 	-Missing values for entry 8: 110
# 	-Missing values for entry 9: 110
# C23_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 132
# 	-Missing values for entry 5: 132
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 355
# 	-Missing values for entry 9: 355
# C19_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 445
# 	-Missing values for entry 5: 445
# 	-Missing values for entry 6: 10
# 	-Missing values for entry 7: 10
# 	-Missing values for entry 8: 600
# 	-Missing values for entry 9: 600
# C22_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 128
# 	-Missing values for entry 5: 128
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 209
# 	-Missing values for entry 9: 209
# C21_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 1
# 	-Missing values for entry 3: 1
# 	-Missing values for entry 4: 339
# 	-Missing values for entry 5: 339
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 303
# 	-Missing values for entry 9: 303
# C15_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 110
# 	-Missing values for entry 5: 110
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 418
# 	-Missing values for entry 9: 418
# C17_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 210
# 	-Missing values for entry 5: 210
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 65
# 	-Missing values for entry 9: 65
# C18_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 2
# 	-Missing values for entry 1: 2
# 	-Missing values for entry 2: 2
# 	-Missing values for entry 3: 2
# 	-Missing values for entry 4: 348
# 	-Missing values for entry 5: 348
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 141
# 	-Missing values for entry 9: 141
# C16_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 231
# 	-Missing values for entry 5: 231
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 408
# 	-Missing values for entry 9: 408
# C9_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 1
# 	-Missing values for entry 3: 1
# 	-Missing values for entry 4: 232
# 	-Missing values for entry 5: 232
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 420
# 	-Missing values for entry 9: 420
# C10_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 5
# 	-Missing values for entry 5: 5
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 30
# 	-Missing values for entry 9: 30
# C3_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 114
# 	-Missing values for entry 5: 114
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 219
# 	-Missing values for entry 9: 219
# C7_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 4
# 	-Missing values for entry 5: 4
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 6
# 	-Missing values for entry 9: 6
# C4_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 40
# 	-Missing values for entry 5: 40
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 166
# 	-Missing values for entry 9: 166
# C2_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 140
# 	-Missing values for entry 5: 140
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 321
# 	-Missing values for entry 9: 321
# C13_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 60
# 	-Missing values for entry 5: 60
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 9
# 	-Missing values for entry 9: 9
# C6_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 117
# 	-Missing values for entry 5: 117
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 122
# 	-Missing values for entry 9: 122
# C1_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 19
# 	-Missing values for entry 5: 19
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C12_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 6
# 	-Missing values for entry 5: 6
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 14
# 	-Missing values for entry 9: 14
# C11_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 46
# 	-Missing values for entry 5: 46
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 1
# 	-Missing values for entry 9: 1
# C14_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 32
# 	-Missing values for entry 3: 32
# 	-Missing values for entry 4: 234
# 	-Missing values for entry 5: 234
# 	-Missing values for entry 6: 14
# 	-Missing values for entry 7: 14
# 	-Missing values for entry 8: 695
# 	-Missing values for entry 9: 695
# C5_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 287
# 	-Missing values for entry 5: 287
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 371
# 	-Missing values for entry 9: 371
# C8_C.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 233
# 	-Missing values for entry 5: 233
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 69
# 	-Missing values for entry 9: 69
# C43_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 13
# 	-Missing values for entry 3: 13
# 	-Missing values for entry 4: 149
# 	-Missing values for entry 5: 149
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 423
# 	-Missing values for entry 9: 423
# C45_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 33
# 	-Missing values for entry 5: 33
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 54
# 	-Missing values for entry 9: 54
# C46_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 1
# 	-Missing values for entry 1: 1
# 	-Missing values for entry 2: 1
# 	-Missing values for entry 3: 1
# 	-Missing values for entry 4: 129
# 	-Missing values for entry 5: 129
# 	-Missing values for entry 6: 1
# 	-Missing values for entry 7: 1
# 	-Missing values for entry 8: 113
# 	-Missing values for entry 9: 113
# C42_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 130
# 	-Missing values for entry 5: 130
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 43
# 	-Missing values for entry 9: 43
# C44_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 255
# 	-Missing values for entry 5: 255
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 40
# 	-Missing values for entry 9: 40
# C41_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 118
# 	-Missing values for entry 5: 118
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 413
# 	-Missing values for entry 9: 413
# C40_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 259
# 	-Missing values for entry 5: 259
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 286
# 	-Missing values for entry 9: 286
# C39_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 0
# 	No missing values for entry 4, filling operation skipped
# 	-Missing values for entry 5: 0
# 	No missing values for entry 5, filling operation skipped
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C38_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 0
# 	No missing values for entry 4, filling operation skipped
# 	-Missing values for entry 5: 0
# 	No missing values for entry 5, filling operation skipped
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C36_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 0
# 	No missing values for entry 4, filling operation skipped
# 	-Missing values for entry 5: 0
# 	No missing values for entry 5, filling operation skipped
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C28_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 1
# 	-Missing values for entry 5: 1
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C33_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 1
# 	-Missing values for entry 5: 1
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 1
# 	-Missing values for entry 9: 1
# C30_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 175
# 	-Missing values for entry 5: 175
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 25
# 	-Missing values for entry 9: 25
# C35_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 236
# 	-Missing values for entry 5: 236
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 526
# 	-Missing values for entry 9: 526
# C34_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 2
# 	-Missing values for entry 1: 2
# 	-Missing values for entry 2: 3
# 	-Missing values for entry 3: 3
# 	-Missing values for entry 4: 110
# 	-Missing values for entry 5: 110
# 	-Missing values for entry 6: 4
# 	-Missing values for entry 7: 4
# 	-Missing values for entry 8: 120
# 	-Missing values for entry 9: 120
# C37_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 0
# 	No missing values for entry 4, filling operation skipped
# 	-Missing values for entry 5: 0
# 	No missing values for entry 5, filling operation skipped
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 0
# 	No missing values for entry 8, filling operation skipped
# 	-Missing values for entry 9: 0
# 	No missing values for entry 9, filling operation skipped
# C26_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 10
# 	-Missing values for entry 5: 10
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 56
# 	-Missing values for entry 9: 56
# C24_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 108
# 	-Missing values for entry 5: 108
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 243
# 	-Missing values for entry 9: 243
# C31_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 114
# 	-Missing values for entry 5: 114
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 52
# 	-Missing values for entry 9: 52
# C29_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 2
# 	-Missing values for entry 1: 2
# 	-Missing values for entry 2: 2
# 	-Missing values for entry 3: 2
# 	-Missing values for entry 4: 396
# 	-Missing values for entry 5: 396
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 374
# 	-Missing values for entry 9: 374
# C27_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 162
# 	-Missing values for entry 5: 162
# 	-Missing values for entry 6: 3
# 	-Missing values for entry 7: 3
# 	-Missing values for entry 8: 40
# 	-Missing values for entry 9: 40
# C25_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 0
# 	No missing values for entry 4, filling operation skipped
# 	-Missing values for entry 5: 0
# 	No missing values for entry 5, filling operation skipped
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 26
# 	-Missing values for entry 9: 26
# C32_S.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 48
# 	-Missing values for entry 5: 48
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 21
# 	-Missing values for entry 9: 21
# C67_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 7
# 	-Missing values for entry 5: 7
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 519
# 	-Missing values for entry 9: 519
# C68_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 14
# 	-Missing values for entry 3: 14
# 	-Missing values for entry 4: 964
# 	-Missing values for entry 5: 964
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 636
# 	-Missing values for entry 9: 636
# C65_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 93
# 	-Missing values for entry 5: 93
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 107
# 	-Missing values for entry 9: 107
# C66_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 35
# 	-Missing values for entry 5: 35
# 	-Missing values for entry 6: 1
# 	-Missing values for entry 7: 1
# 	-Missing values for entry 8: 158
# 	-Missing values for entry 9: 158
# C69_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 6
# 	-Missing values for entry 3: 6
# 	-Missing values for entry 4: 514
# 	-Missing values for entry 5: 514
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 408
# 	-Missing values for entry 9: 408
# C63_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 18
# 	-Missing values for entry 3: 18
# 	-Missing values for entry 4: 452
# 	-Missing values for entry 5: 452
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 403
# 	-Missing values for entry 9: 403
# C61_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 12
# 	-Missing values for entry 5: 12
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 51
# 	-Missing values for entry 9: 51
# C64_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 33
# 	-Missing values for entry 5: 33
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 6
# 	-Missing values for entry 9: 6
# C62_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 56
# 	-Missing values for entry 5: 56
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 36
# 	-Missing values for entry 9: 36
# C60_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 130
# 	-Missing values for entry 5: 130
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 173
# 	-Missing values for entry 9: 173
# C52_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 485
# 	-Missing values for entry 5: 485
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 180
# 	-Missing values for entry 9: 180
# C48_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 35
# 	-Missing values for entry 5: 35
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 58
# 	-Missing values for entry 9: 58
# C53_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 1
# 	-Missing values for entry 3: 1
# 	-Missing values for entry 4: 560
# 	-Missing values for entry 5: 560
# 	-Missing values for entry 6: 1
# 	-Missing values for entry 7: 1
# 	-Missing values for entry 8: 352
# 	-Missing values for entry 9: 352
# C55_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 71
# 	-Missing values for entry 5: 71
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 115
# 	-Missing values for entry 9: 115
# C59_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 324
# 	-Missing values for entry 5: 324
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 86
# 	-Missing values for entry 9: 86
# C47_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 70
# 	-Missing values for entry 5: 70
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 99
# 	-Missing values for entry 9: 99
# C49_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 111
# 	-Missing values for entry 5: 111
# 	-Missing values for entry 6: 2
# 	-Missing values for entry 7: 2
# 	-Missing values for entry 8: 105
# 	-Missing values for entry 9: 105
# C51_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 1
# 	-Missing values for entry 3: 1
# 	-Missing values for entry 4: 197
# 	-Missing values for entry 5: 197
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 373
# 	-Missing values for entry 9: 373
# C58_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 119
# 	-Missing values for entry 5: 119
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 147
# 	-Missing values for entry 9: 147
# C54_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 199
# 	-Missing values for entry 5: 199
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 79
# 	-Missing values for entry 9: 79
# C56_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 285
# 	-Missing values for entry 5: 285
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 404
# 	-Missing values for entry 9: 404
# C50_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 286
# 	-Missing values for entry 5: 286
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 343
# 	-Missing values for entry 9: 343
# C57_A.npy
# 	-Shape: (10, 3480)
# 	-Missing values for entry 0: 0
# 	No missing values for entry 0, filling operation skipped
# 	-Missing values for entry 1: 0
# 	No missing values for entry 1, filling operation skipped
# 	-Missing values for entry 2: 0
# 	No missing values for entry 2, filling operation skipped
# 	-Missing values for entry 3: 0
# 	No missing values for entry 3, filling operation skipped
# 	-Missing values for entry 4: 95
# 	-Missing values for entry 5: 95
# 	-Missing values for entry 6: 0
# 	No missing values for entry 6, filling operation skipped
# 	-Missing values for entry 7: 0
# 	No missing values for entry 7, filling operation skipped
# 	-Missing values for entry 8: 179
# 	-Missing values for entry 9: 179
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
# (8, 3480)
